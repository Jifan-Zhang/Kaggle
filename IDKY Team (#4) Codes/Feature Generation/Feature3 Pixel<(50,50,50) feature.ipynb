# %%
from google.colab import drive
drive.mount("/content/drive/")
from tqdm import tqdm
from PIL import Image
import numpy as np
import pickle

PATH="/content/drive/Shared drives/MyDrive/Kaggle/clips(enhanced) test/"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
with open("/content/drive/Shared drives/MyDrive/Kaggle/clips(enhanced) test/_temp",'w') as f:
    f.write("25000")

# %%
with open("/content/drive/Shared drives/MyDrive/Kaggle/clips(enhanced) test/_temp",'r') as f:
    start=int(f.read())+1
print(f"Starting with {start} picture.")
data=pickle.load(open("/content/drive/Shared drives/MyDrive/Kaggle/Feature Generation (Enhanced)/Real size+grey+50 feature.pkl",'rb'))

for i in range(start,50001):
    filepath=PATH+"clips-"+str(i)+".png"
    count=np.apply_along_axis(lambda x: True if x.max()<50 else False, 2, np.array(Image.open(filepath)))
    data.loc[i,"50"]=count.sum()
    if(i%50==0):
        with open("/content/drive/Shared drives/MyDrive/Kaggle/clips(enhanced) test/_temp",'w') as f:
            f.write(str(i))
        pickle.dump(data,open("/content/drive/Shared drives/MyDrive/Kaggle/Feature Generation (Enhanced)/Real size+grey+50 feature.pkl",'wb'))
    if(i%500==0):
        print(f"{i} completed.")
# Out:
# Starting with 49451 picture.
# 49500 completed.
# 50000 completed.

# %%
with open("/content/drive/Shared drives/MyDrive/Kaggle/clips(enhanced) test/_temp",'r') as f:
    print(int(f.read())+1)
# Out:
# 32251

# %%
pickle.load(open("/content/drive/Shared drives/MyDrive/Kaggle/Feature Generation (Enhanced)/Real size+grey+50 feature.pkl",'rb')).sort_index()
# Out:
#        clip_count     size  grey_pixel_number       50
# id
# 25001         NaN   2868.0              499.0  65050.0
# 25002         NaN  47019.0            10977.0  54836.0
# 25003         NaN  55200.0            12753.0  53104.0
# 25004         NaN   3705.0              627.0  64924.0
# 25005         NaN  45646.0            10110.0  55722.0
# ...           ...      ...                ...      ...
# 49996        35.0  35775.0             7886.0  57833.0
# 49997        54.0  50962.0            11382.0  54432.0
# 49998        72.0  63938.0            15244.0  50704.0
# 49999        24.0  24989.0             5269.0  60416.0
# 50000        35.0  36861.0             8409.0  57366.0
#
# [25000 rows x 4 columns]

# %%
data
